# %% [markdown]
# # CSC 593
#
# ## Week 10

# %% [markdown]
# ### Preparation for the last two weeks of class
#
# Open a Terminal (Mac) or an Anaconda PowerShell Prompt `scikit-image` (might already be there) and `voila`:
#
# ```
# conda install scikit-image
# conda install -c conda-forge voila```

# %%
#### LOAD PACKAGES 
import pandas as pd
import numpy as np
import statsmodels.api as sm
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt

# %matplotlib inline
sns.set()

# %% [markdown]
# ### Linear Regression Analysis

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Rate**: Internet Movie Database user rating (out of 10)
# **User**: Internet Movie Database users rating the movie (in thousands)
# **Meta**: “metascore” based on 35 critic reviews (out of 100)
# **Len**: runtime (in minutes)
# **Win**: award wins
# **Nom**: award nominations

# %%
movies = pd.read_csv('../data/movies.csv')
movies.head()
# Out:
#                                        Movie         Box  Rate     User  Meta  \
# 0  Star Wars: Episode IV - A New Hope (1977)  460.935665   8.8  423.838    91
# 1                         Toy Story 3 (2010)  414.984497   8.5  201.748    92
# 2                        Spider-Man 2 (2004)  373.377893   7.5  191.179    83
# 3                        Finding Nemo (2003)  339.714367   8.1  263.202    89
# 4                       The Lion King (1994)  328.423001   8.3  233.977    83
#
#    Len  Win  Nom  Animated  Superhero
# 0  121   36   22         0          0
# 1  103   35   41         1          0
# 2  127   15   39         0          1
# 3  100   35   36         1          0
# 4   89   27   22         1          0

# %%
plt.figure(figsize=(6,6))
sns.scatterplot('Rate', 'Box', data=movies)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.regplot('Rate', 'Box', data=movies)
plt.show()
# Out:
# C:\Users\sarah.desimone\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#calculates intercept
x = sm.add_constant(movies[['Rate']])
#target variable
y = movies.Box

lm = sm.OLS(y, x).fit()
#calculate R-squared
# Residual Sum of Squares
RSS = sum(lm.resid ** 2)

# Total Sum of Squares
TSS = sum((movies.Box - np.mean(movies.Box)) ** 2)
R2 = 1 - (RSS/TSS)

#print('RSS: {}; TSS: {}; R-squared: {}'.format(RSS, TSS, R2))

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    Box   R-squared:                       0.820
# Model:                            OLS   Adj. R-squared:                  0.812
# Method:                 Least Squares   F-statistic:                     104.5
# Date:                Mon, 25 Nov 2019   Prob (F-statistic):           5.02e-10
# Time:                        16:22:12   Log-Likelihood:                -130.74
# No. Observations:                  25   AIC:                             265.5
# Df Residuals:                      23   BIC:                             267.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -424.4037     63.751     -6.657      0.000    -556.282    -292.526
# Rate          91.7831      8.976     10.225      0.000      73.214     110.352
# ==============================================================================
# Omnibus:                        2.759   Durbin-Watson:                   1.427
# Prob(Omnibus):                  0.252   Jarque-Bera (JB):                2.164
# Skew:                           0.711   Prob(JB):                        0.339
# Kurtosis:                       2.764   Cond. No.                         49.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# **Box(Rate) = -424.4037 + 91.7831Rate** calculated from coeffs constant and Rate

# %%
plt.figure(figsize=(6,6))
sns.lmplot('Rate', 'Box', data=movies)
plt.xlim(4,10)
plt.show()

# %% [markdown]
# #### Practice

# %%
iris = sns.load_dataset('iris')
iris = iris[iris.species=='versicolor']
sns.pairplot(iris)
plt.show()

# %% [markdown]
# Choose a likely pair of variables from the scatterplot matrix above and create a simple model using sm.OLS (call it `lmprac`). Print the model's `.summary()` and write the linear function for the model.

# %%
x = sm.add_constant(iris[['petal_length']])
y = iris.sepal_length

#lmprac = sm.OLS(y, x).fit()

lmprac = sm.OLS(y, x).fit()
#calculate R-squared
# Residual Sum of Squares
RSS = sum(lm.resid ** 2)

# Total Sum of Squares
TSS = sum((iris.sepal_length - np.mean(iris.sepal_length)) ** 2)
R2 = 1 - (RSS/TSS)

#print('RSS: {}; TSS: {}; R-squared: {}'.format(RSS, TSS, R2))

lmprac.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           sepal_length   R-squared:                       0.569
# Model:                            OLS   Adj. R-squared:                  0.560
# Method:                 Least Squares   F-statistic:                     63.26
# Date:                Mon, 25 Nov 2019   Prob (F-statistic):           2.59e-10
# Time:                        16:27:19   Log-Likelihood:                -16.359
# No. Observations:                  50   AIC:                             36.72
# Df Residuals:                      48   BIC:                             40.54
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            2.4075      0.446      5.395      0.000       1.510       3.305
# petal_length     0.8283      0.104      7.954      0.000       0.619       1.038
# ==============================================================================
# Omnibus:                        0.821   Durbin-Watson:                   1.727
# Prob(Omnibus):                  0.663   Jarque-Bera (JB):                0.792
# Skew:                          -0.013   Prob(JB):                        0.673
# Kurtosis:                       2.384   Cond. No.                         41.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #### Adding a predictor, more details

# %%
x = sm.add_constant(movies[['Rate', 'User']])
y = movies.Box

lm = sm.OLS(y, x).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    Box   R-squared:                       0.871
# Model:                            OLS   Adj. R-squared:                  0.859
# Method:                 Least Squares   F-statistic:                     74.15
# Date:                Mon, 25 Nov 2019   Prob (F-statistic):           1.67e-10
# Time:                        12:57:40   Log-Likelihood:                -126.58
# No. Observations:                  25   AIC:                             259.2
# Df Residuals:                      22   BIC:                             262.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -229.0106     86.184     -2.657      0.014    -407.745     -50.276
# Rate          54.9285     14.707      3.735      0.001      24.427      85.430
# User           0.4472      0.152      2.951      0.007       0.133       0.762
# ==============================================================================
# Omnibus:                        9.444   Durbin-Watson:                   1.334
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):                7.427
# Skew:                           1.175   Prob(JB):                       0.0244
# Kurtosis:                       4.268   Cond. No.                     1.87e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.87e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# **Box(Rate, User) = -229.0106 + 54.9285Rate + .4472User** also in coeff column

# %% [markdown]
# #### What matters here:
#
# **P-values** (_P>|t|_ above; `pvalues`): How certain are we that this relationship is meaningful and useful?

# %%
print(lm.pvalues)
print()
print(lm.pvalues['Rate'])
# Out:
# const    8.605905e-07
# Rate     5.016310e-10
# dtype: float64
#
# 5.016310218608222e-10

# %% [markdown]
# **R-squared** (`.rsquared`):  How well does this model explain the data? What fraction of the variation in y is "explained" by the model?
# **Adjusted R-squared** (`.rsquared_adj`):**  R-squared, but "penalized" based on the number of predictors (more predictors &rarr; lower Adjusted R-squared).

# %%
print("R-squared: %2.2f%%" % (lm.rsquared*100))
print("Adjusted R-squared: %2.2f%%" % (lm.rsquared_adj * 100))
# Out:
# R-squared: 81.97%
# Adjusted R-squared: 81.18%

# %% [markdown]
# **Predictions** (`.predict`, `.get_prediction()`): The model's predicted values
# **Residuals** (`.resid`): "Errors". The difference between the predictions and the actual numbers.

# %%
dir(lm)
print("All predictions:", lm.predict())

predict = lm.get_prediction((1, 10, 400))
print()
print("95% confidence interval:", predict.conf_int(alpha=.05))

predict.summary_frame()
# Out:
# All predictions: [383.28789537 355.75295297 263.96981166 319.03969645 337.39632471
#  309.86138232 337.39632471 263.96981166 328.21801058 273.14812579
#  227.25655514 263.96981166 273.14812579 172.18667035 190.54329862
#  181.36498448  62.04690078 153.83004209 163.00835622 117.11678557
#  135.47341383 153.83004209  71.22521491  98.76015731  71.22521491]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-bd7caf3fb726> in <module>
#       2 print("All predictions:", lm.predict())
#       3
# ----> 4 predict = lm.get_prediction((1, 10, 400))
#       5 print()
#       6 print("95% confidence interval:", predict.conf_int(alpha=.05))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in get_prediction(self, exog, transform, weights, row_labels, **kwds)
#    2308         return pred.get_prediction(
#    2309             self, exog=exog, transform=transform, weights=weights,
# -> 2310             row_labels=row_labels, **kwds)
#    2311
#    2312     get_prediction.__doc__ = pred.get_prediction.__doc__
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\regression\_prediction.py in get_prediction(self, exog, transform, weights, row_labels, pred_kwds)
#     159     if pred_kwds is None:
#     160         pred_kwds = {}
# --> 161     predicted_mean = self.model.predict(self.params, exog, **pred_kwds)
#     162
#     163     covb = self.cov_params()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in predict(self, params, exog)
#     343             exog = self.exog
#     344
# --> 345         return np.dot(exog, params)
#     346
#     347     def get_distribution(self, params, scale, exog=None, dist_class=None):
#
# ValueError: shapes (1,3) and (2,) not aligned: 3 (dim 1) != 2 (dim 0)

# %% [markdown]
# **Assumptions**
#
# Residuals should:
#
# 1. have a **mean close to zero** across the distribution;
# 2. have **constant variance** (the vertical spread of the points remains approximately constant across the graph);
# 3. have an approximately **normal distribution**--points tend to be closer to zero on the y axis, with gradually fewer appearing farther away;
# 4. appear **independent** of one another--they seem to be distributed randomly. You shouldn't see a relationship between your input variable(s) and the residuals.
#
# These should be tested with residuals plotted against each predictor variable and the predicted values.

# %%
for x in ('Rate', 'User'):
    plt.figure(figsize=(6,2))
    sns.scatterplot(movies[x], lm.resid)
    plt.title("Residuals by %s" % x)
    plt.ylim(-100, 100)
    #Put a horizontal line through the mean of the predictions.
    plt.axhline(np.mean(lm.resid))
    plt.show()

plt.figure(figsize=(6,2))
sns.scatterplot(lm.predict(), lm.resid)
plt.title("Residuals by Predicted Value")
plt.ylim(-100, 100)
plt.axhline(np.mean(lm.resid))
plt.show()

print(np.mean(lm.resid))
# Out:
# 1.5120349416974933e-13

# %% [markdown]
# #### Practice
#
# Go back to `lmprac` from your last practice. Add a new variable from `iris` to the model, verify that the model is valid, and write the new linear function.

# %%
x = sm.add_constant(iris[['petal_length', 'petal_width']])
y = iris.sepal_length


lmprac = sm.OLS(y, x).fit()
lmprac.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           sepal_length   R-squared:                       0.574
# Model:                            OLS   Adj. R-squared:                  0.556
# Method:                 Least Squares   F-statistic:                     31.71
# Date:                Mon, 25 Nov 2019   Prob (F-statistic):           1.92e-09
# Time:                        16:45:55   Log-Likelihood:                -16.024
# No. Observations:                  50   AIC:                             38.05
# Df Residuals:                      47   BIC:                             43.78
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            2.3806      0.449      5.299      0.000       1.477       3.284
# petal_length     0.9342      0.169      5.517      0.000       0.594       1.275
# petal_width     -0.3200      0.402     -0.795      0.430      -1.129       0.489
# ==============================================================================
# Omnibus:                        1.157   Durbin-Watson:                   1.691
# Prob(Omnibus):                  0.561   Jarque-Bera (JB):                0.947
# Skew:                          -0.005   Prob(JB):                        0.623
# Kurtosis:                       2.326   Cond. No.                         45.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
for x in ('petal_length', 'petal_width'):
    plt.figure(figsize=(6,2))
    sns.scatterplot(iris[x], lmprac.resid)
    plt.title("Residuals by %s" % x)
    plt.ylim(-100, 100)
    #Put a horizontal line through the mean of the predictions.
    plt.axhline(np.mean(lmprac.resid))
    plt.show()

plt.figure(figsize=(6,2))
sns.scatterplot(lmprac.predict(), lmprac.resid)
plt.title("Residuals by Predicted Value")
plt.ylim(-100, 100)
plt.axhline(np.mean(lmprac.resid))
plt.show()

print(np.mean(lmprac.resid))
# Out:
# -1.3322676295501878e-15

# %% [markdown]
# ### Additional notes for time series

# %%
#Setup
temp = pd.read_csv('../data/daily-min-temperatures-melbourne.csv', 
                 index_col="Date", parse_dates=["Date"])

#We can't use pandas datetimes in linear models.
temp['jdate'] = temp.index.to_julian_date()

temp.head()
# Out:
#             Temp      jdate
# Date
# 1981-01-01  20.7  2444605.5
# 1981-01-02  17.9  2444606.5
# 1981-01-03  18.8  2444607.5
# 1981-01-04  14.6  2444608.5
# 1981-01-05  15.8  2444609.5

# %%
plt.figure(figsize=(14,6))
plt.plot(temp.Temp)
plt.show()

# %%
x = sm.add_constant(temp.jdate)
y = temp.Temp

lm = sm.OLS(y, x).fit()

lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Temp   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.5431
# Date:                Mon, 25 Nov 2019   Prob (F-statistic):              0.461
# Time:                        16:59:51   Log-Likelihood:                -10303.
# No. Observations:                3650   AIC:                         2.061e+04
# Df Residuals:                    3648   BIC:                         2.062e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -104.0724    156.393     -0.665      0.506    -410.698     202.553
# jdate       4.711e-05   6.39e-05      0.737      0.461   -7.82e-05       0.000
# ==============================================================================
# Omnibus:                       19.219   Durbin-Watson:                   0.450
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.480
# Skew:                           0.176   Prob(JB):                     5.89e-05
# Kurtosis:                       2.940   Cond. No.                     5.68e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.68e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
plt.figure(figsize=(14,6))
plt.plot(temp.Temp)
plt.plot(temp.index, lm.predict(), 'r-')
plt.show()

# %% [markdown]
# #### Seasonality

# %%
#Reset.
temp = pd.read_csv('../data/daily-min-temperatures-melbourne.csv', 
                 index_col="Date", parse_dates=["Date"])

# %%
from datetime import date
monthnames = [date(2000, x, 1).strftime('%B') for x in range(1, 13)]

months = pd.DataFrame({'month':pd.Categorical(temp.index.strftime('%B'), 
                                              categories=monthnames)}, index = temp.index)
months.month
# Out:
# Date
# 1981-01-01     January
# 1981-01-02     January
# 1981-01-03     January
# 1981-01-04     January
# 1981-01-05     January
# 1981-01-06     January
# 1981-01-07     January
# 1981-01-08     January
# 1981-01-09     January
# 1981-01-10     January
# 1981-01-11     January
# 1981-01-12     January
# 1981-01-13     January
# 1981-01-14     January
# 1981-01-15     January
# 1981-01-16     January
# 1981-01-17     January
# 1981-01-18     January
# 1981-01-19     January
# 1981-01-20     January
# 1981-01-21     January
# 1981-01-22     January
# 1981-01-23     January
# 1981-01-24     January
# 1981-01-25     January
# 1981-01-26     January
# 1981-01-27     January
# 1981-01-28     January
# 1981-01-29     January
# 1981-01-30     January
#                 ...
# 1990-12-02    December
# 1990-12-03    December
# 1990-12-04    December
# 1990-12-05    December
# 1990-12-06    December
# 1990-12-07    December
# 1990-12-08    December
# 1990-12-09    December
# 1990-12-10    December
# 1990-12-11    December
# 1990-12-12    December
# 1990-12-13    December
# 1990-12-14    December
# 1990-12-15    December
# 1990-12-16    December
# 1990-12-17    December
# 1990-12-18    December
# 1990-12-19    December
# 1990-12-20    December
# 1990-12-21    December
# 1990-12-22    December
# 1990-12-23    December
# 1990-12-24    December
# 1990-12-25    December
# 1990-12-26    December
# 1990-12-27    December
# 1990-12-28    December
# 1990-12-29    December
# 1990-12-30    December
# 1990-12-31    December
# Name: month, Length: 3650, dtype: category
# Categories (12, object): [January, February, March, April, ..., September, October, November, December]

# %%
#List of month names.
months = pd.DataFrame({'month':temp.index.strftime('%B')}, index = temp.index)

#Make dummy columns for months.
monthcols = pd.get_dummies(months, drop_first=True)
monthcols
# Out:
#             month_August  month_December  month_February  month_January  \
# Date
# 1981-01-01             0               0               0              1
# 1981-01-02             0               0               0              1
# 1981-01-03             0               0               0              1
# 1981-01-04             0               0               0              1
# 1981-01-05             0               0               0              1
# 1981-01-06             0               0               0              1
# 1981-01-07             0               0               0              1
# 1981-01-08             0               0               0              1
# 1981-01-09             0               0               0              1
# 1981-01-10             0               0               0              1
# 1981-01-11             0               0               0              1
# 1981-01-12             0               0               0              1
# 1981-01-13             0               0               0              1
# 1981-01-14             0               0               0              1
# 1981-01-15             0               0               0              1
# 1981-01-16             0               0               0              1
# 1981-01-17             0               0               0              1
# 1990-12-10  11.0
# 1990-12-11  11.1
# 1990-12-12  14.0
# 1990-12-13  11.4
# 1990-12-14  12.5
# 1990-12-15  13.4
# 1990-12-16  13.6
# 1990-12-17  13.9
# 1990-12-18  17.2
# 1990-12-19  14.7
# 1990-12-20  15.4
# 1990-12-21  13.1
# 1990-12-22  13.2
# 1990-12-23  13.9
# 1990-12-24  10.0
# 1990-12-25  12.9
# 1990-12-26  14.6
# 1990-12-27  14.0
# 1990-12-28  13.6
# 1990-12-29  13.5
# 1990-12-30  15.7
# 1990-12-31  13.0
#
# [3650 rows x 1 columns]

# %%
#Add our dummy month columns to our dataset.
temp = pd.concat((temp, monthcols), axis=1)
temp.head()
# Out:
#             Temp  month_August  month_December  month_February  month_January  \
# Date
# 1981-01-01  20.7             0               0               0              1
# 1981-01-02  17.9             0               0               0              1
# 1981-01-03  18.8             0               0               0              1
# 1981-01-04  14.6             0               0               0              1
# 1981-01-05  15.8             0               0               0              1
#
#             month_July  month_June  month_March  month_May  month_November  \
# Date
# 1981-01-01           0           0            0          0               0
# 1981-01-02           0           0            0          0               0
# 1981-01-03           0           0            0          0               0
# 1981-01-04           0           0            0          0               0
# 1981-01-05           0           0            0          0               0
#
#             month_October  month_September
# Date
# 1981-01-01              0                0
# 1981-01-02              0                0
# 1981-01-03              0                0
# 1981-01-04              0                0
# 1981-01-05              0                0

# %%
x = sm.add_constant(temp.iloc[:,1:])
y = temp.Temp

lm = sm.OLS(y, x).fit()

lm.summary()
# Out:
# D:\tools\anaconda\lib\site-packages\numpy\core\fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# D:\tools\anaconda\lib\site-packages\numpy\core\fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# D:\tools\anaconda\lib\site-packages\numpy\core\fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# D:\tools\anaconda\lib\site-packages\numpy\core\fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# D:\tools\anaconda\lib\site-packages\numpy\core\fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# D:\tools\anaconda\lib\site-packages\numpy\core\fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# D:\tools\anaconda\lib\site-packages\numpy\core\fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# D:\tools\anaconda\lib\site-packages\numpy\core\fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# D:\tools\anaconda\lib\site-packages\numpy\core\fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# D:\tools\anaconda\lib\site-packages\numpy\core\fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# D:\tools\anaconda\lib\site-packages\numpy\core\fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Temp   R-squared:                       0.536
# Model:                            OLS   Adj. R-squared:                  0.535
# Method:                 Least Squares   F-statistic:                     382.6
# Date:                Mon, 25 Nov 2019   Prob (F-statistic):               0.00
# Time:                        12:57:42   Log-Likelihood:                -8900.7
# No. Observations:                3650   AIC:                         1.783e+04
# Df Residuals:                    3638   BIC:                         1.790e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              12.0883      0.160     75.404      0.000      11.774      12.403
# month_August       -4.1970      0.225    -18.663      0.000      -4.638      -3.756
# month_December      1.7636      0.225      7.830      0.000       1.322       2.205
# month_February      3.2854      0.230     14.265      0.000       2.834       3.737
# month_January       2.9420      0.225     13.082      0.000       2.501       3.383
# month_July         -5.3958      0.225    -23.994      0.000      -5.837      -4.955
# month_June         -4.8100      0.227    -21.216      0.000      -5.255      -4.365
# month_March         2.4772      0.225     11.015      0.000       2.036       2.918
# month_May          -2.2219      0.225     -9.880      0.000      -2.663      -1.781
# month_November      0.3913      0.227      1.726      0.084      -0.053       0.836
# month_October      -1.7790      0.225     -7.911      0.000      -2.220      -1.338
# month_September    -3.1120      0.227    -13.726      0.000      -3.557      -2.667
# ==============================================================================
# Omnibus:                       71.674   Durbin-Watson:                   0.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               77.316
# Skew:                           0.323   Prob(JB):                     1.63e-17
# Kurtosis:                       3.301   Cond. No.                         13.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #### [`shift()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.shift.html)

# %%
#Reset.
temp = pd.read_csv('../data/daily-min-temperatures-melbourne.csv', 
                 index_col="Date", parse_dates=["Date"])


temp['temp_last'] = temp.Temp.shift(1)
temp['temp_next'] = temp.Temp.shift(-1)
temp['temp_diff'] = temp.Temp - temp.temp_last
temp.head()
# Out:
#             Temp  temp_last  temp_next  temp_diff
# Date
# 1981-01-01  20.7        NaN       17.9        NaN
# 1981-01-02  17.9       20.7       18.8       -2.8
# 1981-01-03  18.8       17.9       14.6        0.9
# 1981-01-04  14.6       18.8       15.8       -4.2
# 1981-01-05  15.8       14.6       15.8        1.2

# %% [markdown]
# ### Next week
#
# Interactive visualization using Jupyter and [Voila](https://voila.readthedocs.io/en/stable/).
